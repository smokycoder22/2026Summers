# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Parth khismatrao\OneDrive\Desktop\2026Summers\.venv\Scripts\python.exe

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X_train = np.array([
    [1000, 2, 1, 10],
    [1200, 2, 3, 8],
    [1500, 3, 5, 5],
    [1800, 3, 7, 3],
    [2200, 4, 10, 1]
])

y = np.array([50, 60, 75, 90, 110])

# %%
plt.plot(X_train[:,1],y)
plt.xlabel("Rooms")
plt.ylabel("Price")
plt.title("Rooms vs Price")

plt.show()

# %%
feature_names = ["Area", "Rooms", "Floor", "Age"]

fig, ax = plt.subplots(1, 4, figsize=(16,4))

for i in range(4):
    ax[i].plot(X_train[:,i], y)
    ax[i].set_xlabel(feature_names[i])
    ax[i].set_ylabel("Price")

plt.tight_layout()
plt.show()

# %%
feature_names = ["Area", "Rooms", "Floor", "Age"]
plt.figure(figsize=(10,5))

for i in range(4):
    plt.plot(X_train[:,i] , label = feature_names[i])
plt.legend()
plt.xlabel("Index")
plt.ylabel("Price")    
plt.title("house prediction")
plt.show()

# %%
import sys
sys.path.append('../Day7(16_06)')

# %%
from utils import gradient_des
from utils import compute_cost
from utils import compute_gradient

# %%
alphas = [0.0001, 0.001, 0.01, 0.1]
plt.figure(figsize=(10,6))
for alpha in alphas:
    w= np.zeros(X_train.shape[1])
    b =0 
    w, b, J_history = gradient_des(
        X_train , y, w , b , compute_cost , 1000 , compute_gradient , alpha
    )
    plt.plot(J_history, label=f"α = {alpha}")

plt.xlabel("Iterations")
plt.ylabel("Cost J")
plt.title("Gradient Descent Convergence for Different α")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Iteration    0: Cost 206627129.17
# Iteration  100: Cost      inf
# Iteration  200: Cost      nan
# Iteration  300: Cost      nan
# Iteration  400: Cost      nan
# Iteration  500: Cost      nan
# Iteration  600: Cost      nan
# Iteration  700: Cost      nan
# Iteration  800: Cost      nan
# Iteration  900: Cost      nan
# Iteration    0: Cost 20809166209.44
# Iteration  100: Cost      nan
# Iteration  200: Cost      nan
# Iteration  300: Cost      nan
# Iteration  400: Cost      nan
# Iteration  500: Cost      nan
# Iteration  600: Cost      nan
# Iteration  700: Cost      nan
# Iteration  800: Cost      nan
# Iteration  900: Cost      nan
# Iteration    0: Cost 2082383998387.75
# Iteration  100: Cost      nan
# c:\Users\Parth khismatrao\OneDrive\Desktop\2026Summers\Day8(17_06)\../Day7(16_06)\utils.py:29: RuntimeWarning: overflow encountered in scalar power
#   cost = cost + (f_wb_i - y[i])**2       #scalar
# ...

# %%
def zscore_normalization(X):
    mu = np.mean(X,axis =0 )
    sigma = np.std(X, axis=0)
    X_norm = (X-mu)/sigma

    return mu , sigma , X_norm

# %%
mu = np.mean(X_train,axis=0)   
sigma  = np.std(X_train,axis=0) 
X_mean = (X_train - mu)
X_norm = (X_train - mu)/sigma      

fig,ax=plt.subplots(1, 3, figsize=(12, 3))
ax[0].scatter(X_train[:,0], X_train[:,3])
ax[0].set_xlabel(feature_names[0]); ax[0].set_ylabel(feature_names[3]);
ax[0].set_title("unnormalized")
ax[0].axis('equal')

ax[1].scatter(X_mean[:,0], X_mean[:,3])
ax[1].set_xlabel(feature_names[0]); ax[1].set_ylabel(feature_names[3]);
ax[1].set_title(r"X - $\mu$")
ax[1].axis('equal')

ax[2].scatter(X_norm[:,0], X_norm[:,3])
ax[2].set_xlabel(feature_names[0]); ax[2].set_ylabel(feature_names[3]);
ax[2].set_title(r"Z-score normalized")
ax[2].axis('equal')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("distribution of features before, during, after normalization")
plt.show()
